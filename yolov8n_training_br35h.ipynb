# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.6 MB/s eta 0:00:00

# %% [markdown]
# # TRAINING on yolov8n

# %%
from ultralytics import YOLO

# 2. Load pretrained YOLOv8n (good for small medical datasets)
model = YOLO("yolov8n.pt")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.2 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 113.0MB/s 0.1s

# %%
# 3. Train with early stopping

results = model.train(
    data="/content/drive/MyDrive/br35h.yaml",   # path to your dataset yaml
    imgsz=640,           # input size
    epochs=80,           # *max* epochs; training may stop earlier
    batch=4,             # small batch for limited VRAM
    optimizer="SGD",     # aligns with STAR-YOLO setup
    lr0=0.001,           # initial LR
    patience=10,         # stop if no val improvement for 10 epochs
    verbose=True,
    save=True,
    project="runs_br35h",

)
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/br35h.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_br35h, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs_br35h/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 25.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 99.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.8±0.4 ms, read: 0.1±0.0 MB/s, size: 39.9 KB)
# train: Scanning /content/drive/MyDrive/BR35H_roboflow_boxes/labels/train... 561 images, 115 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 561/561 3.5it/s 2:39
# train: New cache created: /content/drive/MyDrive/BR35H_roboflow_boxes/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 2.0±2.2 ms, read: 0.1±0.1 MB/s, size: 52.7 KB)
# val: Scanning /content/drive/MyDrive/BR35H_roboflow_boxes/labels/val... 160 images, 34 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 160/160 3.6it/s 44.2s
# val: New cache created: /content/drive/MyDrive/BR35H_roboflow_boxes/labels/val.cache
# Plotting labels to /content/runs_br35h/train/labels.jpg...
# optimizer: SGD(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs_br35h/train
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80     0.561G      1.179      3.745      1.409          2        640: 100% ━━━━━━━━━━━━ 141/141 7.5it/s 18.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 7.8it/s 2.6s
#                    all        160        129    0.00263      0.977     0.0996     0.0702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80     0.689G     0.9459      3.279      1.244          1        640: 100% ━━━━━━━━━━━━ 141/141 7.9it/s 17.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 9.7it/s 2.1s
#                    all        160        129      0.673      0.256      0.416      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80     0.701G     0.9671       2.58      1.204          1        640: 100% ━━━━━━━━━━━━ 141/141 8.7it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.2it/s 1.6s
#                    all        160        129      0.716       0.62      0.667       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80     0.713G     0.9365      2.243      1.176          1        640: 100% ━━━━━━━━━━━━ 141/141 8.7it/s 16.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.6it/s 1.6s
#                    all        160        129      0.683      0.775      0.736      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80     0.725G     0.9457      2.017      1.199          2        640: 100% ━━━━━━━━━━━━ 141/141 8.4it/s 16.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 7.2it/s 2.8s
#                    all        160        129      0.697      0.819      0.736      0.601
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80     0.736G     0.9319      1.912      1.154          0        640: 100% ━━━━━━━━━━━━ 141/141 8.8it/s 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 11.1it/s 1.8s
#                    all        160        129      0.723      0.809      0.769      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80     0.748G     0.9499      1.775      1.157          0        640: 100% ━━━━━━━━━━━━ 141/141 8.8it/s 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.2it/s 1.6s
#                    all        160        129      0.746      0.844       0.78      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      0.76G     0.8605      1.718      1.104          1        640: 100% ━━━━━━━━━━━━ 141/141 8.7it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 8.5it/s 2.4s
#                    all        160        129      0.753      0.876      0.789      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      0.77G     0.8665      1.597      1.108          1        640: 100% ━━━━━━━━━━━━ 141/141 8.3it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 11.3it/s 1.8s
#                    all        160        129      0.798       0.86      0.813      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80     0.781G     0.8721      1.543      1.116          1        640: 100% ━━━━━━━━━━━━ 141/141 8.7it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.0it/s 1.7s
#                    all        160        129      0.766       0.89      0.806      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80     0.793G     0.8436      1.464      1.096          1        640: 100% ━━━━━━━━━━━━ 141/141 8.7it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 11.2it/s 1.8s
#                    all        160        129      0.782      0.891      0.799      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80     0.805G     0.8485      1.484      1.112          2        640: 100% ━━━━━━━━━━━━ 141/141 8.1it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.3it/s 1.6s
#                    all        160        129      0.767      0.884      0.824      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80     0.816G     0.8492       1.42      1.125          1        640: 100% ━━━━━━━━━━━━ 141/141 8.8it/s 16.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.2it/s 1.6s
#                    all        160        129      0.764      0.845      0.821      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80     0.828G     0.8147      1.402      1.075          1        640: 100% ━━━━━━━━━━━━ 141/141 8.9it/s 15.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 11
7it/s 16.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 7.3it/s 2.7s
#                    all        160        129      0.809      0.917      0.842      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80       1.1G     0.7501      1.081      1.039          2        640: 100% ━━━━━━━━━━━━ 141/141 8.6it/s 16.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 11.9it/s 1.7s
#                    all        160        129      0.804      0.907      0.863       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      1.11G     0.7392      1.085      1.016          0        640: 100% ━━━━━━━━━━━━ 141/141 8.8it/s 15.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.1it/s 1.6s
#                    all        160        129      0.789      0.926      0.858      0.721
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 29, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 39 epochs completed in 0.202 hours.
# Optimizer stripped from /content/runs_br35h/train/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs_br35h/train/weights/best.pt, 6.2MB
#
# Validating /content/runs_br35h/train/weights/best.pt...
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 9.2it/s 2.2s
#                    all        160        129      0.811      0.897      0.846      0.727
# Speed: 0.4ms preprocess, 4.2ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to /content/runs_br35h/train

# %%
# !cp -r /content/runs_br35h /content/drive/MyDrive/

# %% [markdown]
# # EVALUATION of yolov8n model on br35H

# %%
from ultralytics import YOLO
import numpy as np

# 1. Load your trained model
model = YOLO("/content/drive/MyDrive/brain_tumor_det/runs_v8n_br35h_train/train/weights/best.pt")

# 2. Run validation
metrics = model.val(data="/content/drive/MyDrive/brain_tumor_det/br35h.yaml",split="test",project="/content/drive/MyDrive/brain_tumor_det/runs_v8n_br35h_detect")

# 3. Convert arrays to scalars (mean over classes)
prec  = float(np.mean(metrics.box.p))       # precision
rec   = float(np.mean(metrics.box.r))       # recall
map50 = float(np.mean(metrics.box.map50))   # mAP@0.5
map   = float(np.mean(metrics.box.map))     # mAP@0.5:0.95

print(f"Precision:     {prec:.4f}")
print(f"Recall:        {rec:.4f}")
print(f"mAP50:         {map50:.4f}")
print(f"mAP50-95:      {map:.4f}")

print("\nAll metrics dict:")
print(metrics.results_dict)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.247 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 96.8MB/s 0.0s
# val: Fast image access ✅ (ping: 0.7±0.3 ms, read: 0.1±0.0 MB/s, size: 55.9 KB)
# val: Scanning /content/drive/MyDrive/brain_tumor_det/BR35H_roboflow_boxes/labels/test.cache... 80 images, 15 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 106.9Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 24.1s/it 2:01
#                    all         80         70      0.746        0.9      0.817      0.708
# Speed: 10.9ms preprocess, 306.7ms inference, 0.0ms loss, 3.0ms postprocess per image
# Results saved to /content/drive/MyDrive/brain_tumor_det/runs_v8n_br35h_detect/val
# Precision:     0.7456
# Recall:        0.9000
# mAP50:         0.8166
# mAP50-95:      0.7076
#
# All metrics dict:
# {'metrics/precision(B)': 0.7455939171573731, 'metrics/recall(B)': 0.9, 'metrics/mAP50(B)': 0.8165665991209681, 'metrics/mAP50-95(B)': 0.7076343437184376, 'fitness': 0.7076343437184376}

# %%
# !cp -r /content/runs /content/drive/MyDrive/brain_tumor_det

# %%
from IPython.display import Image, display

base = "/content/drive/MyDrive/brain_tumor_det/runs_br35h/train"

# for name in ["results.png", "confusion_matrix.png"]:
print("results.png")
display(Image(filename=f"{base}/{"results.png"}"))

print("confusion_matrix.png")
display(Image(filename=f"{base}/{"confusion_matrix.png"}",width=800))
# Out:
# results.png
# confusion_matrix.png

# %%
for name in ["BoxPR_curve.png","BoxR_curve.png","BoxF1_curve.png"]:
    print(name)
    display(Image(filename=f"{base}/{name}",width=600))
# Out:
# BoxPR_curve.png
# BoxR_curve.png
# BoxF1_curve.png
